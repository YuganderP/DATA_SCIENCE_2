# %% [markdown]
# # Pandas Assessment Notebook (30 Questions)
#
# Covers only the Pandas topics you have revised so far.

# %% [markdown]
# ## Setup (Run First)

# %%
import pandas as pd
import numpy as np

employees_df = pd.DataFrame({
    'EmpID':[101,102,103,104,105],
    'Name':['A','B','C','D','E'],
    'Age':[23,25,np.nan,29,31],
    'Salary':[50000,70000,90000,60000,np.nan],
    'Department':['IT','HR','IT','Sales','HR']
})

sales_df = pd.DataFrame({
    'OrderID':[1,2,3,4],
    'Sales':[1000,1500,1200,1800]
})

bonus_df = pd.DataFrame({
    'EmpID':[101,102,103,106],
    'Bonus':[5000,7000,9000,3000]
})

employees_df
# Out:
#    EmpID Name   Age   Salary Department
# 0    101    A  23.0  50000.0         IT
# 1    102    B  25.0  70000.0         HR
# 2    103    C   NaN  90000.0         IT
# 3    104    D  29.0  60000.0      Sales
# 4    105    E  31.0      NaN         HR

# %% [markdown]
# ## Section A - Series & DataFrame

# %% [markdown]
# Q1. Create a Series containing [10,20,30,40].

# %%
# Write your answer here
a=pd.Series([10,20,30,40])

# %% [markdown]
# Q2. Create a Series with custom index ['a','b','c'] and values [1,2,3].

# %%
# Write your answer here
a=pd.Series([1,2,3],index=['a','b','c'])
a
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# Q3. Create a DataFrame with columns Name and Age.

# %%
# Write your answer here
dic={"Name":['a','b','c','d'],'age':[1,2,3,4]}
a=pd.DataFrame(dic)
a
# Out:
#   Name  age
# 0    a    1
# 1    b    2
# 2    c    3
# 3    d    4

# %% [markdown]
# Q4. What is the difference between Series and DataFrame?

# %%
# Write your answer here
# series is 1 dimensional and cannot contain multiple columns
# DataFrame is 2 or more dimensional and can contain multiple dimensions

# %% [markdown]
# Q5. Why would you use a custom index?

# %%
# Write your answer here
# make data easily readable 
# easily presentable

# %% [markdown]
# ## Section B - loc & iloc

# %% [markdown]
# Q6. Select the Salary column from employees_df.

# %%
# Write your answer here

employees_df['Salary']
# Out:
# 0    50000.0
# 1    70000.0
# 2    90000.0
# 3    60000.0
# 4        NaN
# Name: Salary, dtype: float64

# %% [markdown]
# Q7. Using loc, get the Salary of employee B.

# %%
# Write your answer here
employees_df.loc[:,["Salary"]]
# Out:
#     Salary
# 0  50000.0
# 1  70000.0
# 2  90000.0
# 3  60000.0
# 4      NaN

# %% [markdown]
# Q8. Using iloc, get the Age of the first row.

# %%
# Write your answer here
employees_df.iloc[1,2]
# Out:
# np.float64(25.0)

# %% [markdown]
# Q9. Using loc, get Name and Salary columns of row index 1.

# %%
# Write your answer here
employees_df.loc[1, ["Name","Salary"]]
# Out:
# Name            B
# Salary    70000.0
# Name: 1, dtype: object

# %% [markdown]
# Q10. Explain loc vs iloc.

# %%
# Write your answer here
# loc: label based
# iloc: row , column number based
# Out:
#   Cell In[18], line 2
#     loc: label based
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Section C - Arithmetic Operations

# %% [markdown]
# Q11. Create a new column Tax = Salary * 0.1.

# %%
# Write your answer here
employees_df['Tax']=employees_df['Salary']*0.1
employees_df.head()
# Out:
#    EmpID Name   Age   Salary Department     Tax
# 0    101    A  23.0  50000.0         IT  5000.0
# 1    102    B  25.0  70000.0         HR  7000.0
# 2    103    C   NaN  90000.0         IT  9000.0
# 3    104    D  29.0  60000.0      Sales  6000.0
# 4    105    E  31.0      NaN         HR     NaN

# %% [markdown]
# Q12. Create a new column NetSalary = Salary - Tax.

# %%
# Write your answer here
employees_df['NetSalary']=employees_df['Salary']-employees_df['Tax']
employees_df.head()
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 0    101    A  23.0  50000.0         IT  5000.0    45000.0
# 1    102    B  25.0  70000.0         HR  7000.0    63000.0
# 2    103    C   NaN  90000.0         IT  9000.0    81000.0
# 3    104    D  29.0  60000.0      Sales  6000.0    54000.0
# 4    105    E  31.0      NaN         HR     NaN        NaN

# %% [markdown]
# Q13. Add a constant bonus of 1000 to Salary.

# %%
# Write your answer here
employees_df['Salary']=employees_df['Salary']+1000
employees_df.head()
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 0    101    A  23.0  51000.0         IT  5000.0    45000.0
# 1    102    B  25.0  71000.0         HR  7000.0    63000.0
# 2    103    C   NaN  91000.0         IT  9000.0    81000.0
# 3    104    D  29.0  61000.0      Sales  6000.0    54000.0
# 4    105    E  31.0      NaN         HR     NaN        NaN

# %% [markdown]
# Q14. Give one real-world use of column multiplication.

# %%
# Write your answer here
# example if we we want to to know how much bonus dow the employee gonna earn based on number of years we can multiply no_of_years * percentage per year

# %% [markdown]
# Q15. Filter employees with Salary > 60000.

# %%
# Write your answer here
employees_df[employees_df['Salary']>60000]
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 1    102    B  25.0  71000.0         HR  7000.0    63000.0
# 2    103    C   NaN  91000.0         IT  9000.0    81000.0
# 3    104    D  29.0  61000.0      Sales  6000.0    54000.0

# %% [markdown]
# ## Section D - CSV & Inspection

# %% [markdown]
# Q16. What does read_csv() do?

# %%
# Write your answer here
# reads data from the csv file

# %% [markdown]
# Q17. Explain header vs names.

# %%
# Write your answer here

# header	Specifies which row in the file should be used as the column names.
# names	Assigns custom column names to the DataFrame.

# %% [markdown]
# Q18. Explain usecols.

# %%
# Write your answer here
# selects / get columns mentioned in use cols

# %% [markdown]
# Q19. Explain skiprows.

# %%
# Write your answer here
# skips the rows count mentioned

# %% [markdown]
# Q20. Explain nrows.

# %%
# Write your answer here
# select the num of rows data mentioend here

# %% [markdown]
# ## Section E - Data Inspection

# %% [markdown]
# Q21. Show first 3 rows of employees_df.

# %%
# Write your answer here
employees_df[:3]
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 0    101    A  23.0  51000.0         IT  5000.0    45000.0
# 1    102    B  25.0  71000.0         HR  7000.0    63000.0
# 2    103    C   NaN  91000.0         IT  9000.0    81000.0

# %% [markdown]
# Q22. Show last 2 rows of employees_df.

# %%
# Write your answer here
employees_df[-2:]
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 3    104    D  29.0  61000.0      Sales  6000.0    54000.0
# 4    105    E  31.0      NaN         HR     NaN        NaN

# %% [markdown]
# Q23. Generate summary statistics.

# %%
# Write your answer here
employees_df.describe()
# Out:
#             EmpID        Age        Salary          Tax     NetSalary
# count    5.000000   4.000000      4.000000     4.000000      4.000000
# mean   103.000000  27.000000  68500.000000  6750.000000  60750.000000
# std      1.581139   3.651484  17078.251277  1707.825128  15370.426149
# min    101.000000  23.000000  51000.000000  5000.000000  45000.000000
# 25%    102.000000  24.500000  58500.000000  5750.000000  51750.000000
# 50%    103.000000  27.000000  66000.000000  6500.000000  58500.000000
# 75%    104.000000  29.500000  76000.000000  7500.000000  67500.000000
# max    105.000000  31.000000  91000.000000  9000.000000  81000.000000

# %% [markdown]
# Q24. Convert employees_df to NumPy array.

# %%
# Write your answer here
employees_df.to_numpy()
# Out:
# array([[101, 'A', 23.0, 51000.0, 'IT', 5000.0, 45000.0],
#        [102, 'B', 25.0, 71000.0, 'HR', 7000.0, 63000.0],
#        [103, 'C', nan, 91000.0, 'IT', 9000.0, 81000.0],
#        [104, 'D', 29.0, 61000.0, 'Sales', 6000.0, 54000.0],
#        [105, 'E', 31.0, nan, 'HR', nan, nan]], dtype=object)

# %% [markdown]
# Q25. Sort employees_df by index descending.

# %%
# Write your answer here
employees_df.sort_index(axis=0,ascending=False)
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 4    105    E  31.0      NaN         HR     NaN        NaN
# 3    104    D  29.0  61000.0      Sales  6000.0    54000.0
# 2    103    C   NaN  91000.0         IT  9000.0    81000.0
# 1    102    B  25.0  71000.0         HR  7000.0    63000.0
# 0    101    A  23.0  51000.0         IT  5000.0    45000.0

# %% [markdown]
# ## Section F - Missing Values

# %% [markdown]
# Q26. Find missing values in employees_df.

# %%
# Write your answer here
employees_df.isna()
# Out:
#    EmpID   Name    Age  Salary  Department    Tax  NetSalary
# 0  False  False  False   False       False  False      False
# 1  False  False  False   False       False  False      False
# 2  False  False   True   False       False  False      False
# 3  False  False  False   False       False  False      False
# 4  False  False  False    True       False   True       True

# %% [markdown]
# Q27. Remove rows with missing values.

# %%
# Write your answer here
employees_df.dropna()
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 0    101    A  23.0  51000.0         IT  5000.0    45000.0
# 1    102    B  25.0  71000.0         HR  7000.0    63000.0
# 3    104    D  29.0  61000.0      Sales  6000.0    54000.0

# %% [markdown]
# Q28. Fill missing Age with 0.

# %%
# Write your answer here
employees_df.fillna({'Age':0})
# Out:
#    EmpID Name   Age   Salary Department     Tax  NetSalary
# 0    101    A  23.0  51000.0         IT  5000.0    45000.0
# 1    102    B  25.0  71000.0         HR  7000.0    63000.0
# 2    103    C   0.0  91000.0         IT  9000.0    81000.0
# 3    104    D  29.0  61000.0      Sales  6000.0    54000.0
# 4    105    E  31.0      NaN         HR     NaN        NaN

# %% [markdown]
# Q29. Explain ffill vs bfill.

# %%
# ffill (Forward Fill)
# Copies the PREVIOUS non-null value forward

# bfill (Backward Fill)
# Copies the NEXT non-null value backward

# %% [markdown]
# Q30. When would you use interpolate()?

# %%
# Write your answer here

# Interpolation is used to estimate missing values based on surrounding data, instead of simply copying previous or next values.

# %% [markdown]
# ## Bonus Practice - Merge / Join / Concat (Optional)

# %% [markdown]
# Merge employees_df and bonus_df on EmpID.

# %%
# Write your answer here

# %% [markdown]
# Concatenate employees_df with a copy of itself.

# %%
# Write your answer here

# %% [markdown]
# Join two DataFrames using index.

# %%
# Write your answer here

# %% [markdown]
# # Self Evaluation
#
# | Topic | Score |
# |--------|--------|
# | Series & DataFrame | /5 |
# | loc & iloc | /5 |
# | Arithmetic Operations | /5 |
# | CSV & Inspection | /5 |
# | Data Inspection | /5 |
# | Missing Values | /5 |
#
# **Total: /30**
