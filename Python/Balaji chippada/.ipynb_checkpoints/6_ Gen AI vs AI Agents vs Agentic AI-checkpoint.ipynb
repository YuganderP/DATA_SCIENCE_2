# %% [markdown]
# The AI Stair case
#
# Gen AI -> Gen AI ( tools ) -> AI Agent -> Multi Agent System  -> Full Autonomy

# %% [markdown]
# 1) Gen AI -> Prompt -> text output ( Generation )
# - eg: prompting a question to the GEN AI ( Answer is Generate )

# %% [markdown]
# 2) Tool Usage ( asking ai to look for AI job posted this week and asking which is the best job  The task is done using web search tool of chat gpt
#    - eg: web search tool, we can connect to database using (MCP)

# %% [markdown]
# 3) Building an Agent to Achieve some task
