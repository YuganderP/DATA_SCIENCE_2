# %% [markdown]
# ### how llms are built
# ### LLM : Large language module
# ### 4 stages:
# #### 1st stage(Pre training) : a lot of data is fed on to the Model ( not esentially understanding but infact just knowing the patterns )
# #### 2nd stage( Supervised Fine tuning): set of people testing the model and telling the model how to answer
# #### 3rd RHLF( Renforcement learning from human feedback ): Final model
# #### 4th infrence ( asking questions to the model )

# %% [markdown]
# ### 1st stage: Pretraining
#
# #### Data collection -> common crawl data ( whole of internet data ), Git Hub, Wikipedia, Books, Reddit, Academic Papers, Stack overflow (peta bytes)
# #### Data Cleaning-> Duplicate pages, scrapping low quality data, hate speech, Personal information, all data is passed through a filter to remove
# #### Tokenizer- > convert text -> tokens ( GPT uses byte pair encoding ) -> token id
# #### Embeddings => token id -> length of vector ( king and queen will be close to each others such that symantic meanings of words will be close  )
# #### Neural Networks: -> Attention is all you need paper
# #### Training loop ->  we will ask the questions (at neural network level ) and check if the answer is right and adjust the weights ( if the answer is wrong )

# %% [markdown]
# ### 2nd Staging : Supervised fine tuning
# #### we will ask the answers from the model, the result of this step is instruction tuned model

# %% [markdown]
# #### 4rd RHLf
#
# #### putting guard rails on the model ( feed back )

# %% [markdown]
# ### Inference
#
# #### all the training is done how we will host the model and use this model to get the answer the model.

# %% [markdown]
# #### Hallucinations : making up facts
